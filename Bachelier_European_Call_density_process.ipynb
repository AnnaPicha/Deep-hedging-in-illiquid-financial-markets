# %% [markdown]
# # Deep hedging in illiquid financial markets

# %% [markdown]
# In this Jupyter notebook, we study the problem of hedging a European Call option in an illiquid financial market under a parameter-dependent change of measure by implementing a parameter-dependent density process. We consider a quadratic loss function and an illiquid version of the Bachelier model.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

from keras.models import Sequential

from keras.models import Sequential
from keras.layers import Input, Dense, Conv2D, Concatenate, Dropout, Subtract, \
                        Flatten, MaxPooling2D, Multiply, Lambda, Add, Dot
from keras.backend import constant
from keras import optimizers

from keras.engine.topology import Layer
from keras.models import Model
from keras.layers import Input
from keras import initializers
from keras.constraints import max_norm
from tensorflow.keras.callbacks import EarlyStopping
import keras.backend as K

import matplotlib.pyplot as plt

import copy
import random

import scipy.stats as scipy
from scipy.stats import norm

# %%
N      = 25      # time disrectization
T      = 1       # maturity
strike = 1       # strike for European option
sigma  = 0.3     # volatility
mu     = 0.1     # drift

# %%
kappa1  = 0.5

# %%
def Bachelier(S0, strike, T, sigma):
    return (S0-strike)*scipy.norm.cdf((S0-strike)/(S0*sigma*np.sqrt(T)))+S0*sigma*np.sqrt(T)*scipy.norm.pdf((S0-strike)/(S0*sigma*np.sqrt(T)))

priceBachelier=Bachelier(1,strike,T,sigma)
print(priceBachelier)
# Out:
# 0.1196826841204298

# %%
# Definition of neural networks

m = 1 # dimension of price
d = 2 # number of layers in strategy
n = 5 # nodes in the first (d-1) layers

layers = []
for j in range(N):
    for i in range(d): 
        if i < d-1:
            nodes = n
            layer = Dense(nodes, activation='tanh',trainable=True,
                      kernel_initializer=initializers.RandomNormal(0,1),
                      bias_initializer='random_normal',
                      name=str(i)+str(j))
        else:
            nodes = m
            layer = Dense(nodes, activation='linear', trainable=True,
                          kernel_initializer=initializers.RandomNormal(0,1),
                          bias_initializer='random_normal',
                          name=str(i)+str(j))
        layers = layers + [layer]

# %%
# building up the loss function
kappa = 0

price       = Input(shape=(m,))
hedge       = Input(shape=(m,)) 
premium     = Input(shape=(m,))
sum1_helper = Input(shape=(m,))
sum2_helper = Input(shape=(m,))

inputs  = [price]+[hedge]+[premium]+[sum1_helper]+[sum2_helper]

premium = Dense(m, activation='linear', trainable=True,
                kernel_initializer=initializers.RandomNormal(0,1),
                bias_initializer=initializers.RandomNormal(0,1))(premium)

for j in range(N):
    strategy = price
    for k in range(d):
        strategy = layers[k+(j)*d](strategy) 
    
    # increments of Brownian motion as training data
    incr   = Input(shape = (m,)) 
    inputs = inputs + [incr]
    
    #increment of price process
    priceincr_drift = Lambda(lambda x : (mu+kappa*x)*T/N)(strategy)
    price           = Add()([price, priceincr_drift])
    priceincr_vola  = Lambda(lambda x : sigma*np.sqrt(T)/np.sqrt(N)*x)(incr)
    price           = Add()([price, priceincr_vola])
    
    #increment of wealth process
    wealthincr_drift = Lambda(lambda x : (mu*x+0.5*kappa*x**2)*T/N)(strategy)
    hedge            = Add()([hedge,wealthincr_drift]) 
    wealthincr_vola  = Lambda(lambda x : sigma*np.sqrt(T)/np.sqrt(N)*x)(incr)
    wealthincr_vola  = Multiply()([wealthincr_vola, strategy])
    hedge            = Add()([hedge,wealthincr_vola]) 
    
    #building up density
    helper1     = Lambda(lambda x : (-0.5)*(mu+0.5*kappa*x)/sigma*np.sqrt(T)/np.sqrt(N))(strategy) # 0.5 = square root
    helper1     = Multiply()([helper1,incr])
    sum1_helper = Add()([sum1_helper,helper1]) 
    helper2     = Lambda(lambda x : (-0.25)*K.square(mu+0.5*kappa*x)/K.square(sigma)*T/N)(strategy)# 0.25 = square root*1/2
    sum2_helper = Add()([sum2_helper,helper2])
    
summe   = Add()([sum1_helper,sum2_helper])
density = Lambda(lambda x : K.exp(x))(summe)
payoff  = Lambda(lambda x : K.relu(x-strike))(price) 
outputs = Subtract()([payoff,hedge]) 
outputs = Subtract()([outputs,premium])
outputs = Multiply()([outputs,density])

# %%
learnrate = 0.01
adam = optimizers.Adam(learning_rate=learnrate)
stopping_rule = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 10, restore_best_weights=True)

# %%
bachelier_liquid = Model(inputs=inputs, outputs=outputs)
bachelier_liquid.compile(optimizer=adam, loss='mean_squared_error')

# %%
Ktrain = 2*10**5 


y     = np.random.uniform(0,2,Ktrain)
price = Bachelier(y,strike,T,sigma)


xtrain = ([y]                    + 
          [np.zeros((Ktrain,m))] + 
          [price]                +
          [np.zeros((Ktrain,m))] +
          [np.zeros((Ktrain,m))] +
          [np.random.normal(0,1,(Ktrain,m)) for i in range(N)])

ytrain = np.zeros((Ktrain,1+N))

# %%
history_liquid = bachelier_liquid.fit(x=xtrain, y=ytrain, epochs=150, verbose = 1, batch_size=1024, validation_split=0.2, callbacks=[stopping_rule])
# Out:
# Epoch 1/150
# 157/157 [==============================] - 22s 33ms/step - loss: 0.1168 - val_loss: 0.0026
# Epoch 2/150
# 157/157 [==============================] - 2s 11ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 3/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 4/150
# 157/157 [==============================] - 4s 28ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 5/150
# 157/157 [==============================] - 4s 26ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 6/150
# 157/157 [==============================] - 4s 26ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 7/150
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 8/150
# 157/157 [==============================] - 3s 18ms/step - loss: 0.0011 - val_loss: 9.7774e-04
# Epoch 9/150
# 157/157 [==============================] - 2s 15ms/step - loss: 9.7161e-04 - val_loss: 9.0219e-04
# Epoch 10/150
# 157/157 [==============================] - 2s 14ms/step - loss: 8.6846e-04 - val_loss: 8.1508e-04
# Epoch 11/150
# 157/157 [==============================] - 2s 15ms/step - loss: 7.9122e-04 - val_loss: 7.3766e-04
# Epoch 12/150
# 157/157 [==============================] - 2s 11ms/step - loss: 7.1009e-04 - val_loss: 6.6543e-04
# Epoch 13/150
# 157/157 [==============================] - 2s 13ms/step - loss: 6.5547e-04 - val_loss: 6.1754e-04
# Epoch 14/150
# 157/157 [==============================] - 2s 11ms/step - loss: 6.0854e-04 - val_loss: 5.7744e-04
# Epoch 15/150
# 157/157 [==============================] - 2s 12ms/step - loss: 5.6606e-04 - val_loss: 5.2881e-04
# Epoch 16/150
# 157/157 [==============================] - 2s 14ms/step - loss: 5.3396e-04 - val_loss: 5.0688e-04
# Epoch 17/150
# 157/157 [==============================] - 2s 13ms/step - loss: 5.0663e-04 - val_loss: 4.7133e-04
# Epoch 18/150
150
# 157/157 [==============================] - 2s 14ms/step - loss: 2.6947e-04 - val_loss: 2.6765e-04
# Epoch 87/150
# 157/157 [==============================] - 2s 14ms/step - loss: 2.6903e-04 - val_loss: 2.7387e-04
# Epoch 88/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6751e-04 - val_loss: 2.7003e-04
# Epoch 89/150
# 157/157 [==============================] - 2s 13ms/step - loss: 2.6635e-04 - val_loss: 2.7487e-04
# Epoch 90/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.7736e-04 - val_loss: 2.6400e-04
# Epoch 91/150
# 157/157 [==============================] - 2s 14ms/step - loss: 2.6601e-04 - val_loss: 2.6940e-04
# Epoch 92/150
# 157/157 [==============================] - 2s 14ms/step - loss: 2.6713e-04 - val_loss: 2.7601e-04
# Epoch 93/150
# 157/157 [==============================] - 2s 16ms/step - loss: 2.7096e-04 - val_loss: 2.7280e-04
# Epoch 94/150
# 157/157 [==============================] - 2s 13ms/step - loss: 2.7017e-04 - val_loss: 2.6697e-04
# Epoch 95/150
# 157/157 [==============================] - 2s 13ms/step - loss: 2.6541e-04 - val_loss: 2.6734e-04
# Epoch 96/150
# 157/157 [==============================] - 3s 19ms/step - loss: 2.7086e-04 - val_loss: 2.6729e-04
# Epoch 97/150
# 157/157 [==============================] - 2s 15ms/step - loss: 2.6663e-04 - val_loss: 2.6547e-04
# Epoch 98/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6403e-04 - val_loss: 2.6263e-04
# Epoch 99/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6750e-04 - val_loss: 2.7257e-04
# Epoch 100/150
# 157/157 [==============================] - 2s 13ms/step - loss: 2.6904e-04 - val_loss: 2.7002e-04
# Epoch 101/150
# 157/157 [==============================] - 2s 13ms/step - loss: 2.6947e-04 - val_loss: 2.6404e-04
# Epoch 102/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6432e-04 - val_loss: 2.6615e-04
# Epoch 103/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6547e-04 - val_loss: 2.6902e-04
# Epoch 104/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6500e-04 - val_loss: 2.6521e-04
# Epoch 105/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6299e-04 - val_loss: 2.7145e-04
# Epoch 106/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6839e-04 - val_loss: 2.6588e-04
# Epoch 107/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.6408e-04 - val_loss: 2.6285e-04
# Epoch 108/150
# 157/157 [==============================] - 2s 12ms/step - loss: 2.5876e-04 - val_loss: 2.6397e-04
# Restoring model weights from the end of the best epoch.
# Epoch 00108: early stopping

# %%
plt.figure(figsize=(18, 10))
plt.plot(history_liquid.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.yscale('log')
plt.show()

# %%
# Definition of neural networks 

m = 1 # dimension of price
d = 2 # number of layers in strategy
n = 5 # nodes in the first (d-1) layers

layers_illiquid = []
for j in range(N): 
    for i in range(d):
        if i < d-1:
            nodes = n
            layer = Dense(nodes, activation='tanh',trainable=True,
                      kernel_initializer=initializers.RandomNormal(0,1),
                      bias_initializer='random_normal',
                      name=str(i)+str(j))
        else:
            nodes = m
            layer = Dense(nodes, activation='linear', trainable=True,
                          kernel_initializer=initializers.RandomNormal(0,1),
                          bias_initializer='random_normal',
                          name=str(i)+str(j))
        layers_illiquid = layers_illiquid + [layer]

# %%
# building up the loss function
kappa=kappa1

price       = Input(shape=(m,))
hedge       = Input(shape=(m,)) 
premium     = Input(shape=(m,))
sum1_helper = Input(shape=(m,))
sum2_helper = Input(shape=(m,))

inputs  = [price]+[hedge]+[premium]+[sum1_helper]+[sum2_helper]

premium = Dense(m, activation='linear', trainable=True,
                kernel_initializer=initializers.RandomNormal(0,1),
                bias_initializer=initializers.RandomNormal(0,1))(premium)

for j in range(N):
    strategy = price
    for k in range(d):
        strategy = layers_illiquid[k+(j)*d](strategy) 
    
    # increments of Brownian motion as training data
    incr   = Input(shape = (m,)) 
    inputs = inputs + [incr]
    
    #increment of price process
    priceincr_drift = Lambda(lambda x : (mu+kappa*x)*T/N)(strategy)
    price           = Add()([price, priceincr_drift])
    priceincr_vola  = Lambda(lambda x : sigma*np.sqrt(T)/np.sqrt(N)*x)(incr)
    price           = Add()([price, priceincr_vola])
    
    #increment of wealth process
    wealthincr_drift = Lambda(lambda x : (mu*x+0.5*kappa*x**2)*T/N)(strategy)
    hedge            = Add()([hedge,wealthincr_drift]) 
    wealthincr_vola  = Lambda(lambda x : sigma*np.sqrt(T)/np.sqrt(N)*x)(incr)
    wealthincr_vola  = Multiply()([wealthincr_vola, strategy])
    hedge            = Add()([hedge,wealthincr_vola]) 
    
    #building up density
    helper1     = Lambda(lambda x : (-0.5)*(mu+0.5*kappa*x)/sigma*np.sqrt(T)/np.sqrt(N))(strategy) # 0.5 = square root
    helper1     = Multiply()([helper1,incr])
    sum1_helper = Add()([sum1_helper,helper1]) 
    helper2     = Lambda(lambda x : (-0.25)*K.square(mu+0.5*kappa*x)/K.square(sigma)*T/N)(strategy)# 0.25 = square root*1/2
    sum2_helper = Add()([sum2_helper,helper2])
    
summe   = Add()([sum1_helper,sum2_helper])
density = Lambda(lambda x : K.exp(x))(summe)
payoff  = Lambda(lambda x : K.relu(x-strike))(price) 
outputs = Subtract()([payoff,hedge]) 
outputs = Subtract()([outputs,premium])
outputs = Multiply()([outputs,density])

# %%
bachelier_illiquid = Model(inputs=inputs, outputs=outputs)
bachelier_illiquid.compile(optimizer=adam, loss='mean_squared_error')
history_illiquid   = bachelier_illiquid.fit(x=xtrain, y=ytrain, epochs=150, verbose = 1, batch_size=1024, validation_split=0.2, callbacks=[stopping_rule])
# Out:
# Epoch 1/150
# 157/157 [==============================] - 22s 29ms/step - loss: 0.4542 - val_loss: 0.0096
# Epoch 2/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0072 - val_loss: 0.0043
# Epoch 3/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 4/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 5/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 6/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 7/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 8/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 9/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 10/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 11/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 12/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 13/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 14/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 15/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 16/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 17/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 18/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 19/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 20/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 21/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 22/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 23/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 24/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 25/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 26/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 27/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 28/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 29/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 30/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 31/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 32/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 33/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 34/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 35/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 36/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 37/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 38/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 39/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 40/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 41/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 42/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 43/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 44/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 45/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 46/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 47/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 48/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 49/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 50/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 51/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 52/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 53/150
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 54/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 55/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 56/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 57/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 58/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 59/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 60/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 61/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 62/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 63/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 64/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 65/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 66/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 67/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 68/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 69/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 70/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 71/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 72/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 73/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 74/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 75/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 76/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 77/150
# 157/157 [==============================] - 2s 15ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 78/150
# 157/157 [==============================] - 2s 14ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 79/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 80/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 81/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 82/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 83/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 84/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 85/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 86/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 87/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 88/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 89/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 90/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 91/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 92/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 93/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 94/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 95/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 96/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 97/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 98/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 99/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 100/150
# 157/157 [==============================] - 2s 13ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 101/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 102/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 103/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 104/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 105/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 106/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 107/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 108/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 109/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 110/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 111/150
# 157/157 [==============================] - 2s 12ms/step - loss: 0.0018 - val_loss: 0.0018
# Restoring model weights from the end of the best epoch.
# Epoch 00111: early stopping

# %%
plt.figure(figsize=(18, 10))
plt.plot(history_illiquid.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.yscale('log')
plt.show()
